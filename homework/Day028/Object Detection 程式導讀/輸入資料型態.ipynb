# %%
from data import *
from data import COCODetection
from utils.augmentations import SSDAugmentation

import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.utils.data as data
import torchvision
import torch
import numpy as np
import cv2

# %%
'''transform：自己定義預處理方式'''
'''default會在 annotation資料夾尋找json檔案'''
'''Image default路徑在 images/train2014/'''
'''要先下載coco資料'''
dataset=COCODetection(os.getcwd(),'train2014',transform=SSDAugmentation(300)) 
data_loader=torch.utils.data.DataLoader(dataset,batch_size=1)
batch_iterator = iter(data_loader)
# Out:
# loading annotations into memory...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-02137f420a4d> in <module>()
#       3 '''Image default路徑在 images/train2014/'''
#       4 '''要先下載coco資料'''
# ----> 5 dataset=COCODetection(os.getcwd(),'train2014',transform=SSDAugmentation(300))
#       6 data_loader=torch.utils.data.DataLoader(dataset,batch_size=1)
#       7 batch_iterator = iter(data_loader)
#
# c:\AL\Course\cupoy_電腦視覺與深度學習馬拉松\OpenCV_CVMarathon\homework\Day028\Object Detection 程式導讀\data\coco.py in __init__(self, root, image_set, transform, target_transform, dataset_name)
#      95         from pycocotools.coco import COCO
#      96         self.root = osp.join(root, IMAGES, image_set)
# ---> 97         self.coco = COCO(osp.join(root, ANNOTATIONS,
#      98                                   INSTANCES_SET.format(image_set)))
#      99         self.ids = list(self.coco.imgToAnns.keys())
#
# C:\Users\ASUS\Anaconda3\envs\Pytorch_ENV\lib\site-packages\pycocotools\coco.py in __init__(self, annotation_file)
#      79             print('loading annotations into memory...')
#      80             tic = time.time()
# ---> 81             with open(annotation_file, 'r') as f:
#      82                 dataset = json.load(f)
#      83             assert type(dataset)==dict, 'annotation file format {} not supported'.format(type(dataset))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\AL\\Course\\cupoy_電腦視覺與深度學習馬拉松\\OpenCV_CVMarathon\\homework\\Day028\\Object Detection 程式導讀\\annotations\\instances_train2014.json'

# %% [markdown]
# ---

# %%
images, targets = next(batch_iterator)

# %%
'''Batch size, Channels, Height,Weight'''
print(images.shape)
print(type(images))
# Out:
# torch.Size([1, 3, 300, 300])
# <class 'torch.Tensor'>

# %%
'''Batch size, 標注框數量, (x1,y1,x2,y2,object label)'''
'''此時的x1,y1,x2,y2是經過Normalization，已經除以原圖得高與寬(x/寬,y/高)，縮放到0與1之間'''
print(targets.shape)
print(targets)
print(type(targets))
# Out:
# torch.Size([1, 2, 5])
# tensor([[[ 0.1804,  0.6076,  0.7701,  0.8485, 52.0000],
#          [ 0.2250,  0.0000,  0.9238,  0.5641, 16.0000]]], dtype=torch.float64)
# <class 'torch.Tensor'>

# %% [markdown]
# ---

# %% [markdown]
# ## 如果要自行準備資料，只需要將 input (images, targets)整理得跟上方格式相同即可

# %% [markdown]
# ## 前處理方法可以自訂，如果不使用pretrain weight，不一定要用一樣的前處理，最簡單如所有像素/255即可。
